# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
weekly_2022_11_24 = "Resources/regional-us-weekly-2022-11-24.csv"
weekly_2022_12_01 = "Resources/regional-us-weekly-2022-12-01.csv"
weekly_2022_12_08 = "Resources/regional-us-weekly-2022-12-08.csv"
weekly_2022_12_15 = "Resources/regional-us-weekly-2022-12-15.csv"
weekly_2022_12_22 = "Resources/regional-us-weekly-2022-12-22.csv"
weekly_2022_12_29 = "Resources/regional-us-weekly-2022-12-29.csv"
weekly_2023_01_05 = "Resources/regional-us-weekly-2023-01-05.csv"
weekly_2023_01_12 = "Resources/regional-us-weekly-2023-01-12.csv"
weekly_2023_01_19 = "Resources/regional-us-weekly-2023-01-19.csv"
weekly_2023_01_26 = "Resources/regional-us-weekly-2023-01-26.csv"

# %%
weekly_2022_11_24_df = pd.read_csv(weekly_2022_11_24)
weekly_2022_12_01_df = pd.read_csv(weekly_2022_12_01)
weekly_2022_12_08_df = pd.read_csv(weekly_2022_12_08)
weekly_2022_12_15_df = pd.read_csv(weekly_2022_12_15)
weekly_2022_12_22_df = pd.read_csv(weekly_2022_12_22)
weekly_2022_12_29_df = pd.read_csv(weekly_2022_12_29)
weekly_2023_01_05_df = pd.read_csv(weekly_2023_01_05)
weekly_2023_01_12_df = pd.read_csv(weekly_2023_01_12)
weekly_2023_01_19_df = pd.read_csv(weekly_2023_01_19)
weekly_2023_01_26_df = pd.read_csv(weekly_2023_01_26)

# %%
weekly_2022_12_29_df
# Out:
#      rank                                   uri             artist_names  \
# 0       1  spotify:track:2EjXfH91m7f8HiJN1yQg97               Brenda Lee
# 1       2  spotify:track:1Qrg8KqiBpW07V7PNxwwwL                      SZA
# 2       3  spotify:track:7vQbuQcyTflfCIOu3Uzzya              Bobby Helms
# 3       4  spotify:track:0bYg9bo50gSsH3LtXe2SQn             Mariah Carey
# 4       5  spotify:track:2FRnf9qhLbvw8fu4IBXx78                    Wham!
# ..    ...                                   ...                      ...
# 195   196  spotify:track:6NHpyYvJyQsg2nXXzGYc2R            Morgan Wallen
# 196   197  spotify:track:54ipXppHLA8U4yqpOFTUhr          Imagine Dragons
# 197   198  spotify:track:6pVW5LRWgeLaHudxauOTJU  Daryl Hall & John Oates
# 198   199  spotify:track:26hOm7dTtBi0TdpDGl141t                     Joji
# 199   200  spotify:track:4hTej08FutmriOs7S1hWWy                      SZA
#
#                              track_name                               source  \
# ...

# %%
weekly_2022_11_24_df['chart']='2022_11_24'
weekly_2022_12_01_df['chart']='2022_12_01'
weekly_2022_12_08_df['chart']='2022_12_08'
weekly_2022_12_15_df['chart']='2022_12_15'
weekly_2022_12_22_df['chart']='2022_12_22'
weekly_2022_12_29_df['chart']='2022_12_29'
weekly_2023_01_05_df['chart']='2023_01_05'
weekly_2023_01_12_df['chart']='2023_01_12'
weekly_2023_01_19_df['chart']='2023_01_19'
weekly_2023_01_26_df['chart']='2023_01_26'

# %%
concat_df = pd.concat([weekly_2022_11_24_df, weekly_2022_12_01_df, weekly_2022_12_08_df, weekly_2022_12_15_df, weekly_2022_12_22_df, weekly_2022_12_29_df, weekly_2023_01_05_df, weekly_2023_01_12_df, weekly_2023_01_19_df, weekly_2023_01_26_df])

# %%
concat_df.head()
# Out:
#    rank                                   uri           artist_names  \
# 0     1  spotify:track:1bDbXMyjaUIooNwFE9wn0N       Drake, 21 Savage
# 1     2  spotify:track:0V3wPSX9ygBnCm8psDIegu           Taylor Swift
# 2     3  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy             Steve Lacy
# 3     4  spotify:track:3nqQXoyQOWXiESFLlDF1hG  Sam Smith, Kim Petras
# 4     5  spotify:track:5jQI2r1RdgtuT8S3iG8zFC           Taylor Swift
#
#                   track_name                   source  peak_rank  \
# 0                  Rich Flex   OVO / Republic Records          1
# 1                  Anti-Hero             Taylor Swift          1
# 2                  Bad Habit  L-M Records/RCA Records          1
# 3  Unholy (feat. Kim Petras)                      EMI          1
# 4              Lavender Haze             Taylor Swift          2
#
#    previous_rank  weeks_on_chart   streams       chart
# 0              1               3  13265179  2022_11_24
# ...

# %%
bychart = concat_df.groupby('chart')
bychart.head()
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:1bDbXMyjaUIooNwFE9wn0N
# 1     2  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 2     3  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy
# 3     4  spotify:track:3nqQXoyQOWXiESFLlDF1hG
# 4     5  spotify:track:5jQI2r1RdgtuT8S3iG8zFC
# 0     1  spotify:track:1bDbXMyjaUIooNwFE9wn0N
# 1     2  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 2     3  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 3     4  spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 4     5  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy
# 0     1  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# 1     2  spotify:track:0vjeOZ3Ft5jvAi9SBFJm1j
# 2     3  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 3     4  spotify:track:1bDbXMyjaUIooNwFE9wn0N
# 4     5  spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 0     1  spotify:track:1Qrg8KqiBpW07V7PNxwwwL
# 1     2  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 2     3  spotify:track:5Y35SjAfXjjG0sFQ3KOxmm
# 3     4  spotify:track:2GAhgAjOhEmItWLfgisyOn
# ...

# %%
chart = concat_df.reset_index()
chart.head()
# Out:
#    index  rank                                   uri           artist_names  \
# 0      0     1  spotify:track:1bDbXMyjaUIooNwFE9wn0N       Drake, 21 Savage
# 1      1     2  spotify:track:0V3wPSX9ygBnCm8psDIegu           Taylor Swift
# 2      2     3  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy             Steve Lacy
# 3      3     4  spotify:track:3nqQXoyQOWXiESFLlDF1hG  Sam Smith, Kim Petras
# 4      4     5  spotify:track:5jQI2r1RdgtuT8S3iG8zFC           Taylor Swift
#
#                   track_name                   source  peak_rank  \
# 0                  Rich Flex   OVO / Republic Records          1
# 1                  Anti-Hero             Taylor Swift          1
# 2                  Bad Habit  L-M Records/RCA Records          1
# 3  Unholy (feat. Kim Petras)                      EMI          1
# 4              Lavender Haze             Taylor Swift          2
#
#    previous_rank  weeks_on_chart   streams       chart
# 0              1               3  13265179  2022_11_24
# ...

# %%
chart = chart.drop('index', axis=1)
chart.head()
# Out:
#    rank                                   uri           artist_names  \
# 0     1  spotify:track:1bDbXMyjaUIooNwFE9wn0N       Drake, 21 Savage
# 1     2  spotify:track:0V3wPSX9ygBnCm8psDIegu           Taylor Swift
# 2     3  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy             Steve Lacy
# 3     4  spotify:track:3nqQXoyQOWXiESFLlDF1hG  Sam Smith, Kim Petras
# 4     5  spotify:track:5jQI2r1RdgtuT8S3iG8zFC           Taylor Swift
#
#                   track_name                   source  peak_rank  \
# 0                  Rich Flex   OVO / Republic Records          1
# 1                  Anti-Hero             Taylor Swift          1
# 2                  Bad Habit  L-M Records/RCA Records          1
# 3  Unholy (feat. Kim Petras)                      EMI          1
# 4              Lavender Haze             Taylor Swift          2
#
#    previous_rank  weeks_on_chart   streams       chart
# 0              1               3  13265179  2022_11_24
# ...

# %%
essential_chart = chart.drop(['uri', 'source'], axis=1)
essential_chart.head()
# Out:
#    rank           artist_names                 track_name  peak_rank  \
# 0     1       Drake, 21 Savage                  Rich Flex          1
# 1     2           Taylor Swift                  Anti-Hero          1
# 2     3             Steve Lacy                  Bad Habit          1
# 3     4  Sam Smith, Kim Petras  Unholy (feat. Kim Petras)          1
# 4     5           Taylor Swift              Lavender Haze          2
#
#    previous_rank  weeks_on_chart   streams       chart
# 0              1               3  13265179  2022_11_24
# 1              2               5  11206063  2022_11_24
# 2              3              21   8420594  2022_11_24
# 3              6               9   7550380  2022_11_24
# 4              5               5   6825046  2022_11_24

# %%
essential_chart_grouped = essential_chart.groupby('chart')
essential_chart_grouped.head()
# Out:
#       rank                         artist_names  \
# 0        1                     Drake, 21 Savage
# 1        2                         Taylor Swift
# 2        3                           Steve Lacy
# 3        4                Sam Smith, Kim Petras
# 4        5                         Taylor Swift
# 200      1                     Drake, 21 Savage
# 201      2                           Brenda Lee
# 202      3                         Taylor Swift
# 203      4                         Mariah Carey
# 204      5                           Steve Lacy
# 400      1  Metro Boomin, The Weeknd, 21 Savage
# 401      2    Metro Boomin, Future, Chris Brown
# 402      3                           Brenda Lee
# 403      4                     Drake, 21 Savage
# 404      5                         Mariah Carey
# 600      1                                  SZA
# 601      2                           Brenda Lee
# 602      3                                  SZA
# ...

# %%
essential_chart.to_csv('combined_chart',encoding='utf-8')

# %%
chart_master = "combined_chart"
chart_master_df = pd.read_csv(chart_master)
chart_master_df
# Out:
#       Unnamed: 0  rank           artist_names                    track_name  \
# 0              0     1       Drake, 21 Savage                     Rich Flex
# 1              1     2           Taylor Swift                     Anti-Hero
# 2              2     3             Steve Lacy                     Bad Habit
# 3              3     4  Sam Smith, Kim Petras     Unholy (feat. Kim Petras)
# 4              4     5           Taylor Swift                 Lavender Haze
# ...          ...   ...                    ...                           ...
# 1995        1995   196          Cole Swindell  She Had Me At Heads Carolina
# 1996        1996   197       Drake, 21 Savage            Major Distribution
# 1997        1997   198         Kendrick Lamar                       HUMBLE.
# 1998        1998   199           Trippie Redd                    The Grinch
# 1999        1999   200               80purppp                           Hex
#
# ...
